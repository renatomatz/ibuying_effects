# %%
import pandas as pd

# %%
def standardize(col):
    return (
        col
        .lower()
        .strip()
        .replace("'", "")
        .replace(" ", "_")
        .replace("-", "_")
        .replace(".", "_")
        .replace(",", "_")
        .replace("!", "_")
        .replace("!!", "_")
        .replace("\n", "_")
        .replace("__", "_")
    )

def get_data(file_name, dict_name, data_dict, extra=" by County"):
    for year in [2016, 2019]:
        data_dict[year] = pd.read_csv(f"data/{file_name} {year}{extra}.csv", skiprows=[1]).dropna()
        # data_dict[year].columns = [standardize(col) for col in data_dict[year].columns]
        data_dict[year]["NAME"] = data_dict[year]["NAME"].str.split(",")
        data_dict[year]["county"] = data_dict[year]["NAME"].apply(lambda x: x[0])
        data_dict[year]["state"] = data_dict[year]["NAME"].apply(lambda x: x[1])
        del data_dict[year]["NAME"]
        data_dict[year]["year"] = str(year)
        
        var_dict = pd.read_csv(f"data/dicts/{dict_name}.csv")
        var_dict["id"] = var_dict["id"].str.split("!!").apply(lambda x: x[-1]).apply(standardize)
        vd = {var_dict.iloc[i, 0]:var_dict.iloc[i, 1] for i in range(len(var_dict))}
        data_dict[year] = data_dict[year][["county", "state", "year"] + list(vd.keys())].rename(vd, axis=1)

# %%
soc_char = dict()

get_data("Social Characteristics", "Social Variable", soc_char, extra="")
    
soc_char = pd.concat([*soc_char.values()])
soc_char
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-1e4b71e00b5a> in <module>
#       1 soc_char = dict()
#       2
# ----> 3 get_data("Social Characteristics", "Social Variable", soc_char, extra="")
#       4
#       5 soc_char = pd.concat([*soc_char.values()])
#
# <ipython-input-6-223d9b096ebf> in get_data(file_name, dict_name, data_dict, extra)
#      25         data_dict[year]["year"] = str(year)
#      26
# ---> 27         var_dict = pd.read_csv(f"data/dicts/{dict_name}.csv")
#      28         var_dict["id"] = var_dict["id"].str.split("!!").apply(lambda x: x[-1]).apply(standardize)
#      29         vd = {var_dict.iloc[i, 0]:var_dict.iloc[i, 1] for i in range(len(var_dict))}
#
# ~/.config/miniconda3/lib/python3.8/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
#     687
#     688
#
# ~/.config/miniconda3/lib/python3.8/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     450
#     451     # Create the parser.
# --> 452     parser = TextFileReader(fp_or_buf, **kwds)
#     453
#     454     if chunksize or iterator:
#
# ~/.config/miniconda3/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     944             self.options["has_index_names"] = kwds["has_index_names"]
#     945
# --> 946         self._make_engine(self.engine)
#     947
#     948     def close(self):
#
# ~/.config/miniconda3/lib/python3.8/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1176     def _make_engine(self, engine="c"):
#    1177         if engine == "c":
# -> 1178             self._engine = CParserWrapper(self.f, **self.options)
#    1179         else:
#    1180             if engine == "python":
#
# ~/.config/miniconda3/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    2006         kwds["usecols"] = self.usecols
#    2007
# -> 2008         self._reader = parsers.TextReader(src, **kwds)
#    2009         self.unnamed_cols = self._reader.unnamed_cols
#    2010
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/dicts/Social Variable.csv'

# %%
demo_char = dict()

get_data("Demographic Data", "Demographic Variable", demo_char, extra="")
    
demo_char = pd.concat([*demo_char.values()])
demo_char
# Out:
#                    county         state  year  \
# 0          Autauga County       Alabama  2016
# 1          Baldwin County       Alabama  2016
# 2          Barbour County       Alabama  2016
# 3             Bibb County       Alabama  2016
# 4           Blount County       Alabama  2016
# ...                   ...           ...   ...
# 3215  Vega Baja Municipio   Puerto Rico  2019
# 3216    Vieques Municipio   Puerto Rico  2019
# 3217   Villalba Municipio   Puerto Rico  2019
# 3218    Yabucoa Municipio   Puerto Rico  2019
# 3219      Yauco Municipio   Puerto Rico  2019
#
#       american_indian_and_alaska_native  asian  black_or_african_american  \
# 0                                   2.6    1.6                    55049.0
# 1                                   4.4    3.0                   199510.0
# 2                                   4.3    3.4                    26614.0
# 3                                   2.2    0.8                    22572.0
# 4                                   8.7    8.1                    57704.0
# ...                                 ...    ...                        ...
# 3215                                0.1    0.0                        5.6
# 3216                                0.1    0.2                        8.6
# 3217                                0.1    0.0                       31.3
# 3218                                0.1    0.0                       79.6
# 3219                                0.7    0.0                        4.3
#
#       native_hawaiian_and_other_pacific_islander  some_other_race  white  \
# 0                                            0.4              0.1    1.5
# 1                                            0.4              0.1    1.3
# 2                                            0.1              0.0    4.2
# 3                                            0.1              0.0    0.0
# 4                                            0.2              0.1    0.9
# ...                                          ...              ...    ...
# 3215                                         0.0             11.1   84.1
# 3216                                         0.0             36.5   55.8
# 3217                                         0.0             12.1   85.0
# 3218                                         0.0              1.8   19.6
# 3219                                         0.0             20.2   75.8
#
#       median_age_(years) sex_ratio_(males_per_100_females)
# 0                   37.8                               5.8
# 1                   42.3                               5.7
# 2                   38.7                               5.5
# 3                   40.2                               5.1
# 4                   40.8                               6.1
# ...                  ...                               ...
# 3215              1352.0                               (X)
# 3216               322.0                               (X)
# 3217               206.0                               (X)
# 3218               783.0                               (X)
# 3219               873.0                               (X)
#
# [6440 rows x 11 columns]

# %%
pd.read_csv(f"data/characteristics/dicts/Demographic Variable.csv")
# Out:
#         GEO_ID                                                 id
# 0  DP05_0066PE  Percent!!Race alone or in combination with one...
# 1  DP05_0067PE  Percent!!Race alone or in combination with one...
# 2  DP05_0065PE  Percent!!Race alone or in combination with one...
# 3  DP05_0068PE  Percent!!Race alone or in combination with one...
# 4  DP05_0069PE  Percent!!Race alone or in combination with one...
# 5  DP05_0064PE  Percent!!Race alone or in combination with one...
# 6   DP05_0017E          Estimate!!SEX AND AGE!!Median age (years)
# 7  DP05_0004PE  Percent!!SEX AND AGE!!Total population!!Sex ra...

# %%
econ_char = dict()

get_data("Economic Characteristics", "Economic Variable", econ_char, extra="")
    
econ_char = pd.concat([*econ_char.values()])
econ_char
# Out:
#                       county         state  year  \
# 0             LaSalle County      Illinois  2016
# 1             McHenry County      Illinois  2016
# 2              McLean County      Illinois  2016
# 3               Macon County      Illinois  2016
# 4             Madison County      Illinois  2016
# ..                       ...           ...   ...
# 835          Ponce Municipio   Puerto Rico  2019
# 836       San Juan Municipio   Puerto Rico  2019
# 837       Toa Alta Municipio   Puerto Rico  2019
# 838       Toa Baja Municipio   Puerto Rico  2019
# 839  Trujillo Alto Municipio   Puerto Rico  2019
#
#      mean_travel_time_to_work_(minutes) unemployment_rate  \
# 0                                  24.4               (X)
# 1                                  32.4               (X)
# 2                                  18.3               (X)
# 3                                  17.3               (X)
# 4                                  24.7               (X)
# ..                                  ...               ...
# 835                                23.4               (X)
# 836                                27.0               (X)
# 837                                43.0               (X)
# 838                                31.3               (X)
# 839                                33.8               (X)
#
#      per_capita_income_(dollars)  mean_household_income_(dollars)  \
# 0                          27299                            66763
# 1                          34654                            94250
# 2                          32521                            82471
# 3                          26729                            62668
# 4                          29450                            73318
# ..                           ...                              ...
# 835                        11893                            27761
# 836                        19742                            43536
# 837                        15088                            38502
# 838                        13221                            31892
# 839                        18035                            47738
#
#      median_household_income_(dollars)  \
# 0                                57476
# 1                                81063
# 2                                62156
# 3                                46198
# 4                                56035
# ..                                 ...
# 835                              15130
# 836                              23005
# 837                              28440
# 838                              23368
# 839                              32244
#
#     mean_cash_public_assistance_income_(dollars)  mean_earnings_(dollars)  \
# 0                                           1486                    67658
# 1                                           5029                    95409
# 2                                           1653                    82280
# 3                                           2218                    63336
# 4                                           1672                    72804
# ..                                           ...                      ...
# 835                                         2341                    36196
# 836                                         1782                    55559
# 837                                         2899                    44916
# 838                                         2304                    35590
# 839                                            N                    51357
#
#      mean_retirement_income_(dollars)  mean_social_security_income_(dollars)  \
# 0                               22120                                  19156
# 1                               29106                                  19516
# 2                               32053                                  18604
# 3                               25897                                  18112
# 4                               25648                                  19067
# ..                                ...                                    ...
# 835                             15233                                  13376
# 836                             18862                                  13612
# 837                             18778                                  13651
# 838                             16976                                  14209
# 839                             19062                                  14850
#
#     mean_supplemental_security_income_(dollars)
# 0                                          9293
# 1                                         11040
# 2                                         12843
# 3                                          9602
# 4                                          9247
# ..                                          ...
# 835                                       10055
# 836                                        8665
# 837                                           N
# 838                                           N
# 839                                           N
#
# [1671 rows x 13 columns]

# %%
house_char = dict()

get_data("Housing Characteristics", "Housing Variable", house_char)
    
house_char = pd.concat([*house_char.values()])
house_char
# Out:
#                       county         state  year homeowner_vacancy_rate  \
# 0             LaSalle County      Illinois  2016                    2.7
# 1             McHenry County      Illinois  2016                    2.2
# 2              McLean County      Illinois  2016                    0.7
# 3               Macon County      Illinois  2016                    3.6
# 4             Madison County      Illinois  2016                    3.3
# ..                       ...           ...   ...                    ...
# 835          Ponce Municipio   Puerto Rico  2019                    1.4
# 836       San Juan Municipio   Puerto Rico  2019                    2.3
# 837       Toa Alta Municipio   Puerto Rico  2019                    1.4
# 838       Toa Baja Municipio   Puerto Rico  2019                    1.4
# 839  Trujillo Alto Municipio   Puerto Rico  2019                    2.0
#
#      average_household_size_of_owner_occupied_unit  \
# 0                                             2.47
# 1                                             2.81
# 2                                             2.67
# 3                                             2.42
# 4                                             2.56
# ..                                             ...
# 835                                           2.43
# 836                                           2.31
# 837                                           3.17
# 838                                           2.68
# 839                                           2.77
#
#      average_household_size_of_renter_occupied_unit  median_rooms  \
# 0                                              2.20           5.8
# 1                                              2.57           6.6
# 2                                              2.23           5.7
# 3                                              2.17           5.7
# 4                                              2.22           5.7
# ..                                              ...           ...
# 835                                            2.41           4.9
# 836                                            2.14           4.8
# 837                                            3.11           5.2
# 838                                            2.42           4.7
# 839                                            2.55           4.9
#
#      moved_in_1979_and_earlier  moved_in_1980_to_1989  moved_in_1990_to_1999  \
# 0                         13.2                    7.1                   16.8
# 1                          5.6                    6.1                   18.6
# 2                          5.1                    4.7                   10.0
# 3                         11.2                    6.7                   11.9
# 4                          8.9                    7.7                   15.1
# ..                         ...                    ...                    ...
# 835                       31.3                   15.2                   19.5
# 836                       23.3                   13.2                   19.6
# 837                       26.2                   19.8                   27.5
# 838                       33.3                   12.6                   21.3
# 839                       27.4                   14.4                   28.6
#
#      ...  total_housing_units  10_to_19_units  1_unit_attached  \
# 0    ...                49868             1.6              2.0
# 1    ...               117968             1.9              9.8
# 2    ...                71757             8.4              4.7
# 3    ...                50238             3.4              1.8
# 4    ...               118637             2.7              2.3
# ..   ...                  ...             ...              ...
# 835  ...                66019             4.4              8.1
# 836  ...               190479            10.0              8.6
# 837  ...                26446               N                N
# 838  ...                34618             0.8             13.7
# 839  ...                29601             4.9              8.3
#
#     1_unit_detached 2_units  20_or_more_units 3_or_4_units 5_to_9_units  \
# 0              79.3     4.8               2.5          4.3          2.8
# 1              76.5     1.8               2.6          2.3          4.6
# 2              62.1     3.1               7.5          3.6          6.0
# 3              77.4     1.3               5.8          2.5          4.9
# 4              78.7     3.0               2.7          4.9          2.9
# ..              ...     ...               ...          ...          ...
# 835            73.0     0.5               4.6          3.3          5.6
# 836            44.3     2.4              20.2          4.9          9.4
# 837               N       N                 N            N            N
# 838            64.2     9.0               1.9          5.7          3.3
# 839            58.0     7.8               6.2          4.7         10.2
#
#     boat_rv_van_etc_ mobile_home
# 0                0.0         2.7
# 1                0.0         0.5
# 2                0.0         4.6
# 3                0.0         2.8
# 4                0.0         2.7
# ..               ...         ...
# 835              0.0         0.5
# 836              0.0         0.2
# 837                N           N
# 838              0.0         1.4
# 839              0.0         0.0
#
# [1671 rows x 25 columns]

# %%
all_df = soc_char
for df in [demo_char, econ_char, house_char]:
    all_df = pd.merge(all_df, df, how="left", on=["county", "state", "year"])
    
all_df
# Out:
#                 county       state  year  9th_to_12th_grade_no_diploma  \
# 0       LaSalle County    Illinois  2016                          35.1
# 1       McHenry County    Illinois  2016                          26.5
# 2        McLean County    Illinois  2016                          25.1
# 3         Macon County    Illinois  2016                          34.0
# 4       Madison County    Illinois  2016                          28.8
# ...                ...         ...   ...                           ...
# 1644   Waukesha County   Wisconsin  2019                           2.3
# 1645  Winnebago County   Wisconsin  2019                           5.6
# 1646       Wood County   Wisconsin  2019                           6.1
# 1647    Laramie County     Wyoming  2019                           3.2
# 1648    Natrona County     Wyoming  2019                           5.6
#
#       associates_degree  bachelors_degree  graduate_or_professional_degree  \
# 0                  12.2               6.8                             88.5
# 1                  23.4              10.3                             92.6
# 2                  27.4              16.5                             96.9
# 3                  13.0               8.6                             89.5
# 4                  16.5               9.9                             92.5
# ...                 ...               ...                              ...
# 1644                9.6              30.2                             15.9
# 1645               10.1              22.2                              8.9
# 1646               12.8              12.7                              7.0
# 1647               11.5              17.8                             12.3
# 1648               12.1              14.1                              6.6
#
#       high_school_graduate_(includes_equivalency)  less_than_9th_grade  \
# 0                                            23.7                  8.2
# 1                                            23.8                  4.3
# 2                                            19.5                  2.0
# 3                                            24.4                  7.1
# 4                                            26.8                  6.0
# ...                                           ...                  ...
# 1644                                         21.4                  1.3
# 1645                                         32.3                  2.1
# 1646                                         39.0                  2.8
# 1647                                         28.0                  2.4
# 1648                                         34.4                  1.5
#
#       some_college_no_degree  ...  total_housing_units  10_to_19_units  \
# 0                       10.6  ...                49868             1.6
# 1                        8.5  ...               117968             1.9
# 2                        8.3  ...                71757             8.4
# 3                        9.4  ...                50238             3.4
# 4                       10.6  ...               118637             2.7
# ...                      ...  ...                  ...             ...
# 1644                    19.5  ...               167955             3.6
# 1645                    18.8  ...                76311             4.8
# 1646                    19.6  ...                35479             2.3
# 1647                    24.9  ...                44385             1.5
# 1648                    25.9  ...                37358             2.8
#
#      1_unit_attached  1_unit_detached  2_units 20_or_more_units  3_or_4_units  \
# 0                2.0             79.3      4.8              2.5           4.3
# 1                9.8             76.5      1.8              2.6           2.3
# 2                4.7             62.1      3.1              7.5           3.6
# 3                1.8             77.4      1.3              5.8           2.5
# 4                2.3             78.7      3.0              2.7           4.9
# ...              ...              ...      ...              ...           ...
# 1644             6.2             69.6      2.2              9.6           2.7
# 1645             4.2             63.4      5.4              6.8           4.3
# 1646             1.6             75.2      5.9              7.3           1.9
# 1647            10.7             63.3      2.1              5.0           7.0
# 1648             2.5             68.8      1.2              7.7           3.8
#
#       5_to_9_units  boat_rv_van_etc_  mobile_home
# 0              2.8               0.0          2.7
# 1              4.6               0.0          0.5
# 2              6.0               0.0          4.6
# 3              4.9               0.0          2.8
# 4              2.9               0.0          2.7
# ...            ...               ...          ...
# 1644           5.4               0.0          0.7
# 1645           8.4               0.0          2.7
# 1646           2.4               0.0          3.4
# 1647           3.5               0.2          6.7
# 1648           3.6               0.0          9.7
#
# [1649 rows x 59 columns]

# %%
all_df.to_csv("data/processed/all_chars.csv", index=False)
